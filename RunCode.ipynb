# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "" -d "/content/drive/MyDrive/IITDH/Dataset"

# check need HANN

# %%
# !python3 main.py --config_path "/content/drive/MyDrive/IITDH/Codes/config.ini" \
# --srcdir "" \
# --dstdir "" \
# --labelpath ""

# %%
# !python3 train_sa_e2e.py --savedir "" \
# --train "" \
# --test "" \
# --seed 0 --device 0 --batch 64 --warmup 10 --epochs 60 --dim 23 --lang 3 --model my_sa_model --lr 0.0001 --maxlength 666

# %%
# !python3 train_blstm_e2e.py --savedir "" \
# --train "" \
# --test "" \
# --seed 0 --device 0 --batch 64 --epochs 1 --dim 437 --lang 3 --model my_sa_e2e --lr 0.00001 --lmbda 0.5

# %%
# !python3 train_xsa_e2e.py --savedir "" \
# --train "" \
# --test "" \
# --seed 0 --device 0 --batch 64 --epochs 1 --dim 23 --lang 3 --model my_xsa_model --lr 0.0001 --maxlength 666 --lmbda 0.5

# %% [markdown]
# #***********************************************************************

# %%
# !unzip "/content/drive/MyDrive/IITDH/Zip_folder/PartB_Gujarati-20220526T075746Z-001.zip" -d "/content/drive/MyDrive/IITDH/Dataset"

# %%
# !unzip "/content/drive/MyDrive/IITDH/Zip_folder/PartB_Tamil-20220526T075753Z-001.zip" -d "/content/drive/MyDrive/IITDH/Dataset"

# %%
# !unzip "/content/drive/MyDrive/IITDH/Zip_folder/PartB_Telugu-20220526T075800Z-002.zip" -d "/content/drive/MyDrive/IITDH/Dataset"

# %%
# %cd /content/drive/MyDrive/IITDH/Codes
# Out:
# /content/drive/MyDrive/IITDH/Codes

# %%
# !python3 main.py --config_path "/content/drive/MyDrive/IITDH/Codes/config.ini" \
--srcdir "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Dev/Audio" \
--dstdir "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Dev" \
--labelpath "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Dev/Transcription_LT_Sequence_Frame_Level_200_actual.tsv"

# %%
# !python3 main.py --config_path "/content/drive/MyDrive/IITDH/Codes/config.ini" \
--srcdir "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Train/Audio" \
--dstdir "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Train" \
--labelpath "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Train/Transcription_LT_Sequence_Frame_Level_200_actual.tsv"

# %%
# !python3 main.py --config_path "/content/drive/MyDrive/IITDH/Codes/config.ini" \
--srcdir "/content/drive/MyDrive/IITDH/Dataset/PartB_Tamil/Dev/Audio" \
--dstdir "/content/drive/MyDrive/IITDH/Dataset/PartB_Tamil/Dev" \
--labelpath "/content/drive/MyDrive/IITDH/Dataset/PartB_Tamil/Dev/Transcription_LT_Sequence_Frame_Level_200_actual.tsv"

# %%
# !python3 main.py --config_path "/content/drive/MyDrive/IITDH/Codes/config.ini" \
--srcdir "/content/drive/MyDrive/IITDH/Dataset/PartB_Tamil/Train/Audio" \
--dstdir "/content/drive/MyDrive/IITDH/Dataset/PartB_Tamil/Train" \
--labelpath "/content/drive/MyDrive/IITDH/Dataset/PartB_Tamil/Train/Transcription_LT_Sequence_Frame_Level_200_actual.tsv"

# %%
# !python3 train_blstm_e2e.py --savedir "/content/drive/MyDrive/IITDH/model_save" \
--train "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Train/Data.txt" \
--test "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Dev/Data.txt" \
--seed 0 --device 0 --batch 64 --epochs 1 --dim 437 --lang 3 --model my_sa_e2e --lr 0.00001 --lmbda 0.5
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0% 0/1 [00:00<?, ?it/s]Epoch [1/1], Step [1/135] Loss: 0.7727 CRE: 1.0981 DCL: 0.4473
# Epoch [1/1], Step [26/135] Loss: 0.7628 CRE: 1.0926 DCL: 0.4330
# Epoch [1/1], Step [51/135] Loss: 0.7453 CRE: 1.0865 DCL: 0.4040
# Epoch [1/1], Step [76/135] Loss: 0.7125 CRE: 1.0773 DCL: 0.3476
# Epoch [1/1], Step [101/135] Loss: 0.6904 CRE: 1.0657 DCL: 0.3150
# Epoch [1/1], Step [126/135] Loss: 0.6583 CRE: 1.0392 DCL: 0.2773
# Current Acc.: 67.9513 %
# EER for label 0: 9.2453%
# EER for label 1: 16.0243%
# EER for label 2: 6.7790%
# ...

# %%
# !python3 train_sa_e2e.py --savedir "/content/drive/MyDrive/IITDH/model_save" \
--train "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Train/Data.txt" \
--test "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Dev/Data.txt" \
--seed 0 --device 0 --batch 64 --warmup 10 --epochs 1 --dim 437 --lang 3 --model my_sa_model --lr 0.0001
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0% 0/1 [00:00<?, ?it/s]Epoch [1/1], Step [1/135] Loss: 1.1078
# Epoch [1/1], Step [26/135] Loss: 1.1130
# Epoch [1/1], Step [51/135] Loss: 1.1071
# Epoch [1/1], Step [76/135] Loss: 1.1074
# Epoch [1/1], Step [101/135] Loss: 1.1078
# Epoch [1/1], Step [126/135] Loss: 1.1107
# Current LR: 1e-05
# Current Acc.: 20.9470 %
# EER for label 0: 20.2976%
# EER for label 1: 30.7047%
# EER for label 2: 28.0507%
# EER: 26.3510 %
# New best Acc.: 20.9470%, EER: 26.3510 %, model saved!
# 100% 1/1 [00:32<00:00, 32.15s/it]
# ...

# %%
# !python3 train_xsa_e2e.py --savedir "/content/drive/MyDrive/IITDH/model_save" \
--train "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Train/Data.txt" \
--test "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Dev/Data.txt" \
--seed 0 --device 0 --batch 64 --epochs 1 --dim 23 --lang 3 --model my_xsa_model --lr 0.0001 --maxlength 666 --lmbda 0.5
# Out:
# Current device: cuda:0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0% 0/1 [00:00<?, ?it/s]Epoch [1/1], Step [1/135] Loss: 1.1545 Trans: 1.1937 XV: 1.1153
# Epoch [1/1], Step [26/135] Loss: 0.7219 Trans: 0.7806 XV: 0.6632
# Epoch [1/1], Step [51/135] Loss: 0.6913 Trans: 0.7529 XV: 0.6297
# Epoch [1/1], Step [76/135] Loss: 0.7038 Trans: 0.7453 XV: 0.6623
# Epoch [1/1], Step [101/135] Loss: 0.7197 Trans: 0.7646 XV: 0.6749
# Epoch [1/1], Step [126/135] Loss: 0.7296 Trans: 0.7755 XV: 0.6837
# Current LR: 0.0
# Current Acc.: 78.4149 %
# EER for label 0: 4.2267%
# ...

# %% [markdown]
# #------------------------------------------------------------------------------------------------------------------------------------

# %%
# !python3 train_xsa_e2e.py --savedir "/content/drive/MyDrive/IITDH/model_save" \
--train "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Train/Data.txt" \
--test "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Dev/Data.txt" \
--seed 0 --device 0 --batch 64 --epochs 1 --dim 437 --lang 3 --model my_xsa_model --lr 0.0001 --maxlength 666 --lmbda 0.5
# Out:
# Current device: cuda:0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0% 0/1 [00:00<?, ?it/s]torch.Size([64, 68, 437])
# torch.Size([4352, 437, 1])
#   0% 0/1 [00:03<?, ?it/s]
# Traceback (most recent call last):
#   File "train_xsa_e2e.py", line 161, in <module>
#     main()
#   File "train_xsa_e2e.py", line 108, in main
#     outputs, cnn_outputs = model(utt_, seq_len, atten_mask)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1110, in _call_impl
#     return forward_call(*input, **kwargs)
# ...

# %%
# !python3 train_xsa_e2e.py --savedir "/content/drive/MyDrive/IITDH/model_save" \
--train "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Train/Data.txt" \
--test "/content/drive/MyDrive/IITDH/Dataset/PartB_Gujarati/Dev/Data.txt" \
--seed 0 --device 0 --batch 64 --epochs 1 --dim 23 --lang 3 --model my_xsa_model --lr 0.0001 --maxlength 666 --lmbda 0.5
# Out:
# Current device: cuda:0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0% 0/1 [00:00<?, ?it/s]torch.Size([64, 61, 437])
# torch.Size([3904, 23, 19])
# Epoch [1/1], Step [1/135] Loss: 1.1545 Trans: 1.1937 XV: 1.1153
# torch.Size([64, 64, 437])
# torch.Size([4096, 23, 19])
#   0% 0/1 [00:07<?, ?it/s]
# Traceback (most recent call last):
#   File "train_xsa_e2e.py", line 161, in <module>
#     main()
#   File "train_xsa_e2e.py", line 115, in main
#     loss.backward()
#   File "/usr/local/lib/python3.7/dist-packages/torch/_tensor.py", line 363, in backward
# ...
